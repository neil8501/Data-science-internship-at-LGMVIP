# %% [markdown]
# # Image to pencil sketch with python
#
# ## Task 3

# %% [markdown]
# Importing libraries

# %%
import cv2

# %%
# Read Image

image = cv2.imread("neil.jpg")

# %% [markdown]
# Reading image in RGB Format

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# Converting original image to Greyscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[188, 188, 188, ..., 192, 192, 191],
#        [188, 188, 188, ..., 192, 192, 191],
#        [188, 188, 188, ..., 191, 191, 190],
#        ...,
#        [202, 204, 201, ..., 117, 108, 122],
#        [201, 204, 202, ...,  97, 103,  97],
#        [195, 203, 204, ..., 115, 117, 121]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# Invert image

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image)

# %% [markdown]
# Blur image by Gaussian Function

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.imshow(blurred)

# %% [markdown]
# inverting the Blured image

# %%
inverted_blurred = 255 - blurred 
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)
